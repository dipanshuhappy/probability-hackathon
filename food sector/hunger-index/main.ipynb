# %%
PARTIES_TENTURE=[(0,5,'C'),(4,12,'B')]
PARTIES_TENTURE_TWO=[(0,5,'B'),(4,14,'C'),(13,20,'B')]

# %%
import pandas as pd

hunger_index_df = pd.read_csv("../../GHI from 2011 to 2021.csv")

hunger_index_df
# Out:
#     YEAR   GHI
# 0   2010  21.8
# 1   2011  23.7
# 2   2012  22.9
# 3   2013  21.3
# 4   2014  17.8
# 5   2015  29.0
# 6   2016  28.5
# 7   2017  31.4
# 8   2018  31.1
# 9   2019  30.3
# 10  2020  27.2
# 11  2021  27.5

# %%
import matplotlib.pyplot as plt
GHI_VALUES=hunger_index_df['GHI']
YEARS=hunger_index_df['YEAR']
for tenure in PARTIES_TENTURE:
 if(tenure[2]=='B'):
   plt.plot(YEARS[tenure[0]:tenure[1]]
   ,GHI_VALUES[tenure[0]:tenure[1]],
   color='red',label='BJP')
   plt.legend()
 elif (tenure[2]=='C'):
   plt.plot(YEARS[tenure[0]:tenure[1]],
   GHI_VALUES[tenure[0]:tenure[1]],
   color='blue',label='Congress')
   plt.legend()

# %%
undernorishment_index_df = pd.read_csv("../../UnderNourishMentData.csv")
undernorishment_index_df["Year"]
# Out:
# 0     2001
# 1     2002
# 2     2003
# 3     2004
# 4     2005
# 5     2006
# 6     2007
# 7     2008
# 8     2009
# 9     2010
# 10    2011
# 11    2012
# 12    2013
# 13    2014
# 14    2015
# 15    2016
# 16    2017
# 17    2018
# 18    2019
# 19    2020
# Name: Year, dtype: int64

# %%
import matplotlib.pyplot as plt
VALUES=undernorishment_index_df["Population Percentage under norished"]
YEARS=undernorishment_index_df["Year"]
for tenure in PARTIES_TENTURE_TWO:
 if(tenure[2]=='B'):
   plt.plot(YEARS[tenure[0]:tenure[1]]
   ,VALUES[tenure[0]:tenure[1]],
   color='red')
 elif (tenure[2]=='C'):
   plt.plot(YEARS[tenure[0]:tenure[1]],
   VALUES[tenure[0]:tenure[1]],
   color='blue')
plt.xlim((2001,2020))
plt.show()
