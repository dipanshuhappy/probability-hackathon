# %% [markdown]
# #1project title:Two major political parties of india in terms of food production
#
# This project contains visualistaion,statistics,probability and a bit of prediction

# %%
#intialize Constants
PARTIES_TENTURE=[(0,4,'B'),(3,12,'C'),(11,14,'B')]

# %%
import pandas as pd

food_average_yeild = pd.read_csv("../../All India level Average Yield of Principal Crops from 2001-02 to 2015-16.csv")
food_average_yeild
# Out:
#             Year  Foodgrains(cereals) - Rice  Foodgrains(cereals) - Wheat  \
# 0        2001-02                        20.8                         27.6
# 1        2002-03                        17.4                         26.1
# 2        2003-04                        20.8                         27.1
# 3        2004-05                        19.8                         26.0
# 4        2005-06                        21.0                         26.2
# 5        2006-07                        21.3                         27.1
# 6        2007-08                        22.0                         28.0
# 7        2008-09                        21.8                         29.1
# 8        2009-10                        21.3                         28.4
# 9        2010-11                        22.4                         29.9
# 10       2011-12                        23.9                         31.8
# 11       2012-13                        24.6                         31.2
# 12       2013-14                        24.2                         31.5
# 13       2014-15                        23.9                         27.5
# 14  2015-16(A E)                         NaN                          NaN
#
#     Foodgrains(cereals) - Jowar  Foodgrains(cereals) - Bajra  \
# 0                           7.7                          8.7
# 1                           7.5                          6.1
# 2                           7.2                         11.4
# 3                           8.0                          9.6
# 4                           8.8                          8.0
# 5                           8.4                          8.9
# 6                          10.2                         10.4
# 7                           9.6                         10.2
# 8                           8.6                          7.3
# 9                           9.5                         10.8
# 10                          9.6                         11.7
# 11                          8.5                         12.0
# 12                          9.6                         11.8
# 13                          8.8                         12.6
# 14                          NaN                          NaN
#
#     Foodgrains(cereals) - Maize  Foodgrains(cereals) - Ragi  \
# 0                          20.0                        14.4
# 1                          16.8                         9.3
# 2                          20.4                        11.8
# 3                          19.1                        15.7
# 4                          19.4                        15.3
# 5                          19.1                        12.3
# 6                          23.4                        15.5
# 7                          24.1                        14.8
# 8                          20.2                        14.9
# 9                          25.4                        17.1
# 10                         24.8                        16.4
# 11                         25.7                        13.9
# 12                         26.8                        16.6
# 13                         26.3                        17.1
# 14                          NaN                         NaN
#
#     Foodgrains(cereals) - Small millets  Foodgrains(cereals) - Barley  \
# 0                                   4.4                          21.6
# 1                                   3.8                          20.1
# 2                                   4.7                          19.8
# 3                                   4.3                          19.6
# 4                                   4.4                          19.4
# 5                                   4.7                          20.5
# 6                                   5.3                          19.8
# 7                                   4.9                          23.9
# 8                                   4.6                          21.7
# 9                                   5.5                          23.6
# 10                                  5.7                          25.2
# 11                                  5.8                          25.2
# 12                                  6.3                          27.2
# 13                                  6.5                          23.2
# 14                                  NaN                           NaN
#
#     Foodgrains(cereals) - Total cereals  ...  Rubber  Banana (MT/ha)  \
# 0                                  19.8  ...    15.7            26.9
# 1                                  17.5  ...    15.9            26.0
# 2                                  19.8  ...    16.6            29.2
# 3                                  19.0  ...    17.0            29.0
# 4                                  19.7  ...    18.0            28.6
# 5                                  20.2  ...    18.8            34.8
# 6                                  21.5  ...    18.0            36.2
# 7                                  21.8  ...    18.7            34.4
# 8                                  20.8  ...    17.8            34.4
# 9                                  22.6  ...    18.1            35.9
# 10                                 24.2  ...    18.4            35.7
# 11                                 24.5  ...    18.1            34.2
# 12                                 24.6  ...    14.9            37.0
# 13                                 23.3  ...     NaN            33.3
# 14                                  NaN  ...     NaN             NaN
#
#     Sugar -  cane  Tobacco  Potatoes (MT/ha)  Pepper (black)  Chillies  \
# 0           673.7     15.7              19.8             2.8      12.1
# 1           635.8     15.3              17.3             3.2      10.8
# 2           593.9     14.9              17.9             3.1      16.0
# 3           647.5     15.0              17.9             3.2      16.1
# 4           669.2     14.8              17.1             3.6      15.5
# 5           690.2     14.1              14.9             2.8      16.3
# 6           688.8     14.2              19.3             2.4      16.1
# 7           645.5     14.6              18.8             2.0      16.3
# 8           700.2     15.6              19.9             2.6      15.7
# 9           700.9     17.9              22.7             2.8      15.4
# 10          716.7     16.1              21.8             2.1      15.9
# 11          682.5     15.4              22.8             4.2      16.4
# 12          705.2     18.1              21.1             4.1      19.3
# 13          715.1      NaN              22.2             4.4      19.3
# 14            NaN      NaN               NaN             NaN       NaN
#
#     Ginger  Coconut  Turmeric
# 0     35.3     67.1      33.7
# 1     31.8     65.2      34.8
# 2     35.5     63.0      37.6
# 3     37.7     66.3      45.2
# 4     35.4     76.1      49.5
# 5     37.1     81.8      44.1
# 6     36.8     77.5      45.3
# 7     35.0     52.3      45.4
# 8     35.8     57.1      43.8
# 9     47.1     57.2      50.9
# 10    48.8     72.1      53.3
# 11    50.2     73.0      50.1
# 12    49.2     69.7      51.1
# 13    51.0     71.6      45.1
# 14     NaN      NaN       NaN
#
# [15 rows x 36 columns]

# %% [markdown]
# #Getting The average of the food product using panda in below code

# %%
AVERAGE_FOOD_YIELD=food_average_yeild.mean(axis=1)
AVERAGE_FOOD_YIELD
# Out:
# C:\Users\DPS\AppData\Local\Temp\ipykernel_19512\416698859.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   AVERAGE_FOOD_YIELD=food_average_yeild.mean(axis=1)
# 0     36.311765
# 1     33.717647
# 2     34.217647
# 3     35.841176
# 4     35.647059
# 5     36.391176
# 6     36.941176
# 7     34.958824
# 8     36.358824
# 9     38.017647
# 10    39.220588
# 11    38.252941
# 12    39.411765
# 13    40.606250
# 14     8.800000
# dtype: float64

# %%
#Normalizaing Years
YEARS=[ x[:4] for x in food_average_yeild['Year']]

# %% [markdown]
# ## Below is visualization of food production from 2001 to 2016
# Note - Red represents BJP and Blue represent Congress

# %%
import matplotlib.pyplot as plt
#print(years)

for tenure in PARTIES_TENTURE:
 if(tenure[2]=='B'):
   plt.plot(YEARS[tenure[0]:tenure[1]]
   ,AVERAGE_FOOD_YIELD[tenure[0]:tenure[1]],
   color='red')
 elif (tenure[2]=='C'):
   plt.plot(YEARS[tenure[0]:tenure[1]],
   AVERAGE_FOOD_YIELD[tenure[0]:tenure[1]],
   color='blue')
plt.xticks(rotation=90)
plt.show()
