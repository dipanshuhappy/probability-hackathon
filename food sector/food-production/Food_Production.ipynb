# %% [markdown]
# #project title:Two major political parties of india in terms of food production
# This project contains visualistaion,statistics,probability and a bit of prediction

# %%
import pandas as pd
import numpy as np

#df1 = pd.read_csv("All India level Average Yield of Principal Crops from 2001-02 to 2015-16.csv")
df1 = pd.read_csv('../../All India level Average Yield of Principal Crops from 2001-02 to 2015-16.csv')

df1
# Out:
#        Year  Foodgrains(cereals) - Rice  Foodgrains(cereals) - Wheat  \
# 0   2001-02                        20.8                         27.6
# 1   2002-03                        17.4                         26.1
# 2   2003-04                        20.8                         27.1
# 3   2004-05                        19.8                         26.0
# 4   2005-06                        21.0                         26.2
# 5   2006-07                        21.3                         27.1
# 6   2007-08                        22.0                         28.0
# 7   2008-09                        21.8                         29.1
# 8   2009-10                        21.3                         28.4
# 9   2010-11                        22.4                         29.9
# 10  2011-12                        23.9                         31.8
# 11  2012-13                        24.6                         31.2
# 12  2013-14                        24.2                         31.5
# ...

# %%
sum1_row = df1.sum(axis=1)
print (sum1_row)
# Out:
# 0     1251.4
# 1     1162.8
# 2     1180.3
# 3     1236.0
# 4     1229.1
# 5     1254.5
# 6     1273.1
# 7     1205.4
# 8     1253.3
# 9     1309.3
# 10    1352.4
# 11    1320.2
# 12    1361.4
# 13    1353.5
# dtype: float64
# /var/folders/kk/n7by4v5n3hdgjsgy_q7g6_h80000gn/T/ipykernel_14373/3684474026.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   sum1_row = df1.sum(axis=1)

# %%
import matplotlib.pyplot as plt
rice=df1['Foodgrains(cereals) - Rice']
wheat=df1['Foodgrains(cereals) - Wheat']
Jowar=df1['Foodgrains(cereals) - Jowar']
year=df1['Year']
fig=plt.figure()
myaxes=fig.add_axes([0.1,0.1,1.6,1.6])
myaxes.plot(year,rice,'r',lw=3,label='Rice')
myaxes.plot(year,wheat,'b',lw=3,label='wheat')
myaxes.legend()
myaxes.set_xlabel("Timeline")
myaxes.set_ylabel("Foodgrains")
myaxes.set_title("All India level Average Yield of Principal Crops from 2001-02 to 2015-16")
# Out:
# Text(0.5, 1.0, 'All India level Average Yield of Principal Crops from 2001-02 to 2015-16')

# %%
df1['Target'] = sum1_row

# %%
df1
# Out:
#        Year  Foodgrains(cereals) - Rice  Foodgrains(cereals) - Wheat  \
# 0   2001-02                        20.8                         27.6
# 1   2002-03                        17.4                         26.1
# 2   2003-04                        20.8                         27.1
# 3   2004-05                        19.8                         26.0
# 4   2005-06                        21.0                         26.2
# 5   2006-07                        21.3                         27.1
# 6   2007-08                        22.0                         28.0
# 7   2008-09                        21.8                         29.1
# 8   2009-10                        21.3                         28.4
# 9   2010-11                        22.4                         29.9
# 10  2011-12                        23.9                         31.8
# 11  2012-13                        24.6                         31.2
# 12  2013-14                        24.2                         31.5
# ...

# %%
Y = df1['Target']

# %%
features = pd.read_csv("../../All India level Average Yield of Principal Crops from 2001-02 to 2015-16.csv", usecols = ['Foodgrains(cereals) - Rice','Foodgrains(cereals) - Wheat','Foodgrains(cereals) - Jowar','Foodgrains(cereals) - Bajra','Foodgrains(cereals) - Maize','Foodgrains(cereals) - Ragi','Foodgrains(cereals) - Small millets','Foodgrains(cereals) - Barley','Foodgrains(pulses) - Tur','Foodgrains(pulses) - Gram','Foodgrains(pulses) - Other pulses','Foodgrains(pulses) - Total pulses','Total Food - grains','Oilseeds - Groundnuts','Oilseeds - Sesamum','Oilseeds - Rapeseed & mustard','Oilseeds - Linseed','Oilseeds - Casterseed','Oilseeds - Total oilseeds','Cotton','Jute','Mesta','Tea','Coffee','Rubber','Banana (MT/ha)','Sugar -  cane','Tobacco','Potatoes (MT/ha)','Pepper (black)','Chillies','Ginger','Coconut','Turmeric'])

# %%
features.to_numpy()
# Out:
# array([[ 20.8,  27.6,   7.7,   8.7,  20. ,  14.4,   4.4,  21.6,   6.8,
#           8.5,   4.6,   6.1,  17.3,  11.3,   4.2,  10. ,   3.9,   9.1,
#           9.1,   1.9,  21.8,  62.8,  16.8,   9.4,  15.7,  26.9, 673.7,
#          15.7,  19.8,   2.8,  12.1,  35.3,  67.1,  33.7],
#        [ 17.4,  26.1,   7.5,   6.1,  16.8,   9.3,   3.8,  20.1,   6.5,
#           7.2,   4.2,   5.4,  15.3,   6.9,   3.1,   8.5,   3.9,   7.3,
#           6.9,   1.9,  21.4,  58.6,  16.4,   8.6,  15.9,  26. , 635.8,
#          15.3,  17.3,   3.2,  10.8,  31.8,  65.2,  34.8],
#        [ 20.8,  27.1,   7.2,  11.4,  20.4,  11.8,   4.7,  19.8,   6.7,
#           8.1,   5.3,   6.4,  17.3,  13.6,   4.6,  11.6,   4.1,  11.1,
#          10.6,   3.1,  21.7,  60.2,  16.9,   8.3,  16.6,  29.2, 593.9,
#          14.9,  17.9,   3.1,  16. ,  35.5,  63. ,  37.6],
#        [ 19.8,  26. ,   8. ,   9.6,  19.1,  15.7,   4.3,  19.6,   6.7,
#           8.1,   4.2,   5.8,  16.5,  10.2,   3.7,  10.4,   3.8,  10.7,
# ...

# %%
features.shape
# Out:
# (14, 34)

# %%
X = df1.drop(['Target','Year'], axis = 1)
X
# Out:
#     Foodgrains(cereals) - Rice  Foodgrains(cereals) - Wheat  \
# 0                         20.8                         27.6
# 1                         17.4                         26.1
# 2                         20.8                         27.1
# 3                         19.8                         26.0
# 4                         21.0                         26.2
# 5                         21.3                         27.1
# 6                         22.0                         28.0
# 7                         21.8                         29.1
# 8                         21.3                         28.4
# 9                         22.4                         29.9
# 10                        23.9                         31.8
# 11                        24.6                         31.2
# 12                        24.2                         31.5
# 13                        23.9                         27.5
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
X_train.shape, Y_train.shape
# Out:
# ((11, 35), (11,))

# %%
Y_test
# Out:
# 6     1273.1
# 11    1320.2
# 8     1253.3
# Name: Target, dtype: float64

# %%
X_test.shape, Y_test.shape
# Out:
# ((3, 35), (3,))

# %%
import numpy as np
np.array(Y_test)
# Out:
# array([1273.1, 1320.2, 1253.3])

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
model = linear_model.LinearRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X_test)

# %%
print('Coefficients:', model.coef_)
print('Intercept:', model.intercept_)
print('Mean squared error (MSE): %.2f'
      % mean_squared_error(Y_test, Y_pred))
print('Coefficient of determination (R^2): %.2f'
      % r2_score(Y_test, Y_pred))
# Out:
# Coefficients: [-0.86951802 -0.25202489 -0.38549335  3.18409991 -0.61585745 -2.93276006
#   1.33794129  3.55626212 -1.66199205  0.54071401 -1.03589432  0.68420401
#   1.6282455  -2.29319621  4.42644313  1.29785845  2.16754279  1.72980006
#   2.78869733  3.23241859 -0.15872618 -1.15405416  1.07705042  4.54650351
#  -0.769522    3.62520458  0.2209804   1.46843583 -0.88820231  2.24957798
#  -0.21283784  1.84410689 -0.2853364   0.46812449  1.47022355]
# Intercept: -137.17187212451563
# Mean squared error (MSE): 150.20
# Coefficient of determination (R^2): 0.81

# %%
r2_score(Y_test, Y_pred)
# Out:
# 0.8092367657707303

# %%
r2_score(Y_test, Y_pred).dtype
# Out:
# dtype('float64')

# %%
import seaborn as sns

# %%
Y_test
# Out:
# 6     1273.1
# 11    1320.2
# 8     1253.3
# Name: Target, dtype: float64

# %%
import numpy as np
np.array(Y_test)
# Out:
# array([1273.1, 1320.2, 1253.3])

# %%
Y_pred
# Out:
# array([1270.02001184, 1300.57484866, 1260.78021941])

# %%
plt.scatter(Y_test,Y_pred)

# %%
plt.scatter(Y_test, Y_pred, marker="+")

# %%
Y_pred = model.predict(X_test)

# %%
print(Y_pred)
# Out:
# [1270.02001184 1300.57484866 1260.78021941]

# %%
plt.plot(Y_test, Y_pred, marker="+", x_="red")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/swaraj/developer/Probability/probability-hackathon/food sector/food-production/Food_Production.ipynb Cell 35 in <module>
# ----> <a href='vscode-notebook-cell:/Users/swaraj/developer/Probability/probability-hackathon/food%20sector/food-production/Food_Production.ipynb#X46sZmlsZQ%3D%3D?line=0'>1</a> plt.plot(Y_test, Y_pred, marker="+", x_="red")
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/pyplot.py:2767, in plot(scalex, scaley, data, *args, **kwargs)
#    2765 @_copy_docstring_and_deprecators(Axes.plot)
#    2766 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2767     return gca().plot(
#    2768         *args, scalex=scalex, scaley=scaley,
#    2769         **({"data": data} if data is not None else {}), **kwargs)
#
# ...

# %%
[Y_test, Y_pred]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/swaraj/developer/Probability/probability-hackathon/food sector/food-production/Food_Production.ipynb Cell 36 in <module>
# ----> <a href='vscode-notebook-cell:/Users/swaraj/developer/Probability/probability-hackathon/food%20sector/food-production/Food_Production.ipynb#X50sZmlsZQ%3D%3D?line=0'>1</a> [Y_test, Y_pred]
#
# NameError: name 'Y_pred' is not defined

# %%
import datetime

def str_to_datetime(s):
  split = s.split('-')
  year = int(split[0])
  return datetime.datetime(year=year,month=1,day=1)

datetime_object = str_to_datetime('1986-87')
datetime_object
# Out:
# datetime.datetime(1986, 1, 1, 0, 0)

# %%
df1['Year'] = df1['Year'].apply(str_to_datetime)

# %%
df1['Year']
# Out:
# 0    2001-01-01
# 1    2002-01-01
# 2    2003-01-01
# 3    2004-01-01
# 4    2005-01-01
# 5    2006-01-01
# 6    2007-01-01
# 7    2008-01-01
# 8    2009-01-01
# 9    2010-01-01
# 10   2011-01-01
# 11   2012-01-01
# 12   2013-01-01
# 13   2014-01-01
# Name: Year, dtype: datetime64[ns]

# %%
df1.index = df1.pop('Year')

# %%
df1
# Out:
#             Foodgrains(cereals) - Rice  Foodgrains(cereals) - Wheat  \
# Year
# 2001-01-01                        20.8                         27.6
# 2002-01-01                        17.4                         26.1
# 2003-01-01                        20.8                         27.1
# 2004-01-01                        19.8                         26.0
# 2005-01-01                        21.0                         26.2
# 2006-01-01                        21.3                         27.1
# 2007-01-01                        22.0                         28.0
# 2008-01-01                        21.8                         29.1
# 2009-01-01                        21.3                         28.4
# 2010-01-01                        22.4                         29.9
# 2011-01-01                        23.9                         31.8
# 2012-01-01                        24.6                         31.2
# 2013-01-01                        24.2                         31.5
# ...

# %%
def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date
  
  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)
    
    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Target'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True
    
  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]
  
  ret_df['Target'] = Y

  return ret_df

# %%
windowed_df = df_to_windowed_df(df1, 
                                '2005-01-01', 
                                '2014-01-01', 
                                n=1)
                                
windowed_df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/swaraj/developer/Probability/probability-hackathon/food sector/food-production/Food_Production.ipynb Cell 43 in <module>
# ----> <a href='vscode-notebook-cell:/Users/swaraj/developer/Probability/probability-hackathon/food%20sector/food-production/Food_Production.ipynb#X60sZmlsZQ%3D%3D?line=0'>1</a> windowed_df = df_to_windowed_df(df1,
#       <a href='vscode-notebook-cell:/Users/swaraj/developer/Probability/probability-hackathon/food%20sector/food-production/Food_Production.ipynb#X60sZmlsZQ%3D%3D?line=1'>2</a>                                 '2005-01-01',
#       <a href='vscode-notebook-cell:/Users/swaraj/developer/Probability/probability-hackathon/food%20sector/food-production/Food_Production.ipynb#X60sZmlsZQ%3D%3D?line=2'>3</a>                                 '2014-01-01',
# ...
