# %%
#intialize Constants
PARTIES_TENTURE=[(0,5,'B'),(4,15,'C'),(14,21,'B')]

# %%
import pandas as pd

farmers_related = pd.read_csv("../../Farmer Suicide from 2000 to 2020.csv")
farmers_related
# Out:
#     Year Farmer Suicide
# 0   2000         16,603
# 1   2001         16,415
# 2   2002          17971
# 3   2003         17,164
# 4   2004         18,241
# 5   2005         17,131
# 6   2006         17,060
# 7   2007         16,632
# 8   2008         16,796
# 9   2009         17,368
# 10  2010         15,964
# 11  2011         14,027
# 12  2012         13,754
# 13  2013         11,772
# 14  2014         12,360
# 15  2015         12,602
# 16  2016         11,379
# 17  2017         10,655
# 18  2018         10,349
# 19  2019         10,281
# 20  2020         10,677

# %%
farmers_related["Year"]
farmers_related["Farmer Suicide"]
# Out:
# 0     16,603
# 1     16,415
# 2      17971
# 3     17,164
# 4     18,241
# 5     17,131
# 6     17,060
# 7     16,632
# 8     16,796
# 9     17,368
# 10    15,964
# 11    14,027
# 12    13,754
# 13    11,772
# 14    12,360
# 15    12,602
# 16    11,379
# 17    10,655
# 18    10,349
# 19    10,281
# 20    10,677
# Name: Farmer Suicide, dtype: object

# %%
import matplotlib.pyplot as plt
#print(years)
YEARS=farmers_related["Year"]
legend_one_shown=False
leegend_two_shown=False
for tenure in PARTIES_TENTURE:
 if(tenure[2]=='B'):
   plt.plot(YEARS[tenure[0]:tenure[1]]
   ,farmers_related["Farmer Suicide"][tenure[0]:tenure[1]],
   color='red',label='BJP')
   if(legend_one_shown==False):
      plt.legend()
      legend_one_shown=True
   

 elif (tenure[2]=='C'):
   plt.plot(YEARS[tenure[0]:tenure[1]],
   farmers_related["Farmer Suicide"][tenure[0]:tenure[1]],
   color='blue',label='Congress')
   plt.legend()
plt.xticks(range(2000,2021),rotation=90)
plt.title("Farmer Suicides in India")
plt.xlabel("Year")
plt.ylabel("Farmer Suicide")
plt.gca().invert_yaxis()
plt.show()
