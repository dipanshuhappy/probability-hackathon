# %%
import pandas as pd
import numpy as np
import plotly.express as px
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler 
plt.style.use('fivethirtyeight')

# %%
unemployment = pd.read_csv('../india-unemployment-rate.csv')
unemployment
# Out:
#     years   Unemployment Rate (%)   Annual Change
# 0    1991                   5.599            0.00 NaN
# 1    1992                   5.727            0.13 NaN
# 2    1993                   5.691           -0.04 NaN
# 3    1994                   5.739            0.05 NaN
# 4    1995                   5.755            0.02 NaN
# 5    1996                   5.740           -0.01 NaN
# 6    1997                   5.613           -0.13 NaN
# 7    1998                   5.666            0.05 NaN
# 8    1999                   5.736            0.07 NaN
# 9    2000                   5.561           -0.18 NaN
# 10   2001                   5.576            0.01 NaN
# 11   2002                   5.530           -0.05 NaN
# 12   2003                   5.643            0.11 NaN
# 13   2004                   5.629           -0.01 NaN
# 14   2005                   5.613           -0.02 NaN
# 15   2006                   5.601           -0.01 NaN
# ...

# %%
years = unemployment['years']
unemploymentRate = unemployment[' Unemployment Rate (%)']

# %%
plt.plot(years,unemploymentRate)

# %%
import sys
sys.path.append('/Users/swaraj/developer/Probability/probability-hackathon/Prediction')

# %%
import linerRegression as lr

# %%
import datetime

def str_to_datetime(s):
  year = int(s)
  return datetime.datetime(year=year,month=1,day=1)

datetime_object = str_to_datetime('1986')
datetime_object
# Out:
# datetime.datetime(1986, 1, 1, 0, 0)

# %%
unemployment
# Out:
#     years   Unemployment Rate (%)   Annual Change
# 0    1991                   5.599            0.00 NaN
# 1    1992                   5.727            0.13 NaN
# 2    1993                   5.691           -0.04 NaN
# 3    1994                   5.739            0.05 NaN
# 4    1995                   5.755            0.02 NaN
# 5    1996                   5.740           -0.01 NaN
# 6    1997                   5.613           -0.13 NaN
# 7    1998                   5.666            0.05 NaN
# 8    1999                   5.736            0.07 NaN
# 9    2000                   5.561           -0.18 NaN
# 10   2001                   5.576            0.01 NaN
# 11   2002                   5.530           -0.05 NaN
# 12   2003                   5.643            0.11 NaN
# 13   2004                   5.629           -0.01 NaN
# 14   2005                   5.613           -0.02 NaN
# 15   2006                   5.601           -0.01 NaN
# ...

# %%
unemployment['years'] = unemployment['years'].apply(str_to_datetime)

# %%
x = unemployment[' Annual Change']
y = unemployment[' Unemployment Rate (%)']
x,y
abs(x)
# Out:
# 0     0.00
# 1     0.13
# 2     0.04
# 3     0.05
# 4     0.02
# 5     0.01
# 6     0.13
# 7     0.05
# 8     0.07
# 9     0.18
# 10    0.01
# 11    0.05
# 12    0.11
# 13    0.01
# 14    0.02
# 15    0.01
# 16    0.03
# 17    0.16
# 18    0.13
# 19    0.00
# 20    0.12
# 21    0.01
# 22    0.01
# 23    0.01
# 24    0.00
# 25    0.01
# 26    0.07
# 27    0.03
# 28    0.06
# 29    2.73
# 30    2.02
# Name:  Annual Change, dtype: float64

# %%
x.shape
import numpy as np

# %%
x = np.array(x).reshape(-1,1)

# %%
lr.linerRegression(abs(x),y)
# Out:
# Coefficients:
#  [0.20581404]
# Mean squared error: 0.52
# Variance score: 0.32
# array([5.55856588, 6.11220564, 5.55239146, 5.55239146, 5.55650774,
#        5.55239146, 5.55239146])
