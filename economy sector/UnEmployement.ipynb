# %%
import pandas as pd
import numpy as np
import plotly.express as px
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler 
plt.style.use('fivethirtyeight')

# %%
unemployment = pd.read_csv('../india-unemployment-rate.csv')
unemployment
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 unemployment = pd.read_csv('gindia-unemployment-rate.csv')
#       2 unemployment
#
# File c:\Users\DPS\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
years = unemployment['years']
unemploymentRate = unemployment[' Unemployment Rate (%)']

# %%
plt.plot(years,unemploymentRate)

# %% [markdown]
# >Because of Covid in 2020there was higher rate of unemployment
