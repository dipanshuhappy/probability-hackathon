# %%
import pandas as pd
import numpy as np
import plotly.express as px
import numpy as np
import matplotlib.pyplot as plt

# %%
local_bodies_public_sector = pd.read_csv('../State-wise employment in local bodies of public Sector till March 2011.csv')

# %%
march2001 = local_bodies_public_sector['March ending 2001'].mean()

# %%
march2001
# Out:
# 75.34666666666666

# %%
march2003 = local_bodies_public_sector['March ending 2003'].mean()

# %%
march2005 = local_bodies_public_sector['March ending 2005'].mean()

# %%
march2008 = local_bodies_public_sector['March ending 2008'].mean()

# %%
march2009 = local_bodies_public_sector['March ending 2009'].mean()

# %%
march2010 = local_bodies_public_sector['March ending 2010'].mean()

# %%
march2011 = local_bodies_public_sector['March ending 2011'].mean()

# %%
march2003,march2005,march2008,march2009,march2010,march2011
# Out:
# (72.61333333333333,
#  68.31290322580645,
#  65.56666666666666,
#  68.93333333333334,
#  69.66666666666667,
#  70.72413793103448)

# %%
years = ['2003','2005','2008','2009','2010','2011']
means = [march2003,march2005,march2008,march2009,march2010,march2011]

# %%
local_bodies_public_sector.plot()
# Out:
# <AxesSubplot:>

# %%
plt.plot(years,means)

# %%
local_bodies_2014_2016_means = pd.read_csv('../Employed from 2016 to 2020.csv')

# %%
local_bodies_2014_2016_means
x = local_bodies_2014_2016_means['YEAR']
y = local_bodies_2014_2016_means['EMPLOYED(in M)']

# %%
plt.plot(x,y)

# %%
#allYears = np.concatenate(years + x)

# %%
def meargeArray(x,y):
    for i in range(len(y)):
        x.append(y[i])
    return x

# %%
allYears = meargeArray(years,x)

# %%
allMeans = meargeArray(means,y)

# %%
plt.plot(allYears,allMeans)
print(allMeans)
# Out:
# [72.61333333333333, 68.31290322580645, 65.56666666666666, 68.93333333333334, 69.66666666666667, 70.72413793103448, 465.8, 464.6, 464.6, 475.8, 485.5, 447.1]
