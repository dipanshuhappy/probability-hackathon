# %%
#intialize Constants
PARTIES_TENTURE=[(0,4,'B'),(3,12,'C'),(11,14,'B')]

# %%
import pandas as pd
water_data=pd.read_csv('../UNICEF water data from 2000 to 2020 CSV.csv')
water_data
# Out:
#                                              DATAFLOW  \
# 0   UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 1   UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 2   UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 3   UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 4   UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 5   UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 6   UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 7   UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 8   UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 9   UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 10  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 11  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 12  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 13  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 14  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 15  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# ...

# %%
waterdata1=pd.read_csv('../UNICEF water data from 2000 to 2020 CSV.csv',nrows=20)


waterdata1
# Out:
#                                              DATAFLOW  \
# 0   UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 1   UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 2   UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 3   UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 4   UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 5   UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 6   UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 7   UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 8   UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 9   UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 10  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 11  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 12  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 13  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 14  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 15  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# ...

# %%
waterdata2=pd.read_csv('../UNICEF water data from 2000 to 2020 CSV.csv',skiprows=range(1,23),nrows=21)
waterdata2
# Out:
#                                              DATAFLOW  \
# 0   UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 1   UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 2   UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 3   UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 4   UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 5   UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 6   UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 7   UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 8   UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 9   UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 10  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 11  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 12  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 13  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 14  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 15  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(len(waterdata1['TIME_PERIOD:Time period']))
YEARS=waterdata1['TIME_PERIOD:Time period']
# width = .5
# fig, ax = plt.subplots()
# bar2 = ax.bar(x + width/2, waterdata2['OBS_VALUE:Observation Value'], width, label='Surface Water')
 
#ax.set_xlabel('Year')
YEARS=YEARS[::-1]
COLORS=[]
for year in YEARS:
    for tenure in PARTIES_TENTURE:
        year=int(year)
        if(year>=YEARS[tenure[0]] and year<=YEARS[tenure[1]-1]):
            if(tenure[2]=='B'):
                COLORS.append("red")
            else:
                COLORS.append("blue")
# ax.set_ylabel('Observation value')

# ax.set_xticks(x, waterdata1['TIME_PERIOD:Time period'])
# bar1 = ax.bar(x - width/2, waterdata1['OBS_VALUE:Observation Value'], width, label='Improved Drinking Water',colors=COLORS)
plt.bar(YEARS,waterdata1['OBS_VALUE:Observation Value'],color=COLORS)
 
#setting bar labels
# ax.bar_label(bar1,rotation=90)
# ax.bar_label(bar2,rotation=90)
 
# fig.tight_layout()
plt.xticks(rotation=90)
plt.show()

# %%
waterdata1.sort_values(by='OBS_VALUE:Observation Value', inplace=True, ascending=True)

# %%
plt.savefig(filename+'.png', facecolor=(.94, .94, .94))

# %%
import matplotlib.pyplot as plt
#print(years)
legend_one_shown=False
leegend_two_shown=False
for tenure in PARTIES_TENTURE:
 if(tenure[2]=='B'):
   plt.plot(YEARS[tenure[0]:tenure[1]]
   ,AVERAGE_FOOD_YIELD[tenure[0]:tenure[1]],
   color='red',label='BJP')
   if(legend_one_shown==False):
      plt.legend()
      legend_one_shown=True
   

 elif (tenure[2]=='C'):
   plt.plot(YEARS[tenure[0]:tenure[1]],
   AVERAGE_FOOD_YIELD[tenure[0]:tenure[1]],
   color='blue',label='Congress')
   plt.legend()
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\myday\Desktop\probability hackathon\probability-hackathon\water_resources\water_data.ipynb Cell 14 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/myday/Desktop/probability%20hackathon/probability-hackathon/water_resources/water_data.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> for tenure in PARTIES_TENTURE:
#       <a href='vscode-notebook-cell:/c%3A/Users/myday/Desktop/probability%20hackathon/probability-hackathon/water_resources/water_data.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a>  if(tenure[2]=='B'):
#       <a href='vscode-notebook-cell:/c%3A/Users/myday/Desktop/probability%20hackathon/probability-hackathon/water_resources/water_data.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a>    plt.plot(YEARS[tenure[0]:tenure[1]]
# ...
